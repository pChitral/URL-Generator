# %%
import pandas as pd

# %%
df = pd.read_csv(r'file_name.csv')

maal = df

# %%
columnsList = []

for i in range (30):
    columns = (list(maal.columns))
    columnsList.append((columns[i]))

# %%
for group in columnsList:
    
    for i in range(30):
        word = maal[group][i]
        url = f'https://sentence.yourdictionary.com/{word}'
        print(url)
# Out:
# https://sentence.yourdictionary.com/abound
# https://sentence.yourdictionary.com/amorphous
# https://sentence.yourdictionary.com/austere
# https://sentence.yourdictionary.com/belie
# https://sentence.yourdictionary.com/capricious
# https://sentence.yourdictionary.com/cerebral
# https://sentence.yourdictionary.com/congenial
# https://sentence.yourdictionary.com/conspicuous
# https://sentence.yourdictionary.com/cursory
# https://sentence.yourdictionary.com/daunting
# https://sentence.yourdictionary.com/deify
# https://sentence.yourdictionary.com/didactic
# https://sentence.yourdictionary.com/disseminate
# https://sentence.yourdictionary.com/feasible
# https://sentence.yourdictionary.com/flout
# https://sentence.yourdictionary.com/homogeneous
# https://sentence.yourdictionary.com/humdrum
# https://sentence.yourdictionary.com/insipid
# https://sentence.yourdictionary.com/loquacious
# https://sentence.yourdictionary.com/misanthropic
# https://sentence.yourdictionary.com/misnomer
# ...

# %%
# allWords = {}
# groupIterate = []

# for j in range(0,1):
#     group = columnsList[j]
#     groupIterate.clear()
#     for i in range(30):
#         word = maal[group][i]
#         url = f'https://www.vocabulary.com/dictionary/{word}'
#         groupIterate.append(url)
#     allWords[group] = groupIterate

# %%
allWords = {}
for j in range(0, 30):
    group = columnsList[j]
    groupIterate = []
    for i in range(30):
        word = maal[group][i]
        url =f'https://sentence.yourdictionary.com/{word}'
        groupIterate.append(url)
    allWords[group] = groupIterate

# %%
allWords
# Out:
# {'Group 1': ['https://sentence.yourdictionary.com/abound',
#   'https://sentence.yourdictionary.com/amorphous',
#   'https://sentence.yourdictionary.com/austere',
#   'https://sentence.yourdictionary.com/belie',
#   'https://sentence.yourdictionary.com/capricious',
#   'https://sentence.yourdictionary.com/cerebral',
#   'https://sentence.yourdictionary.com/congenial',
#   'https://sentence.yourdictionary.com/conspicuous',
#   'https://sentence.yourdictionary.com/cursory',
#   'https://sentence.yourdictionary.com/daunting',
#   'https://sentence.yourdictionary.com/deify',
#   'https://sentence.yourdictionary.com/didactic',
#   'https://sentence.yourdictionary.com/disseminate',
#   'https://sentence.yourdictionary.com/feasible',
#   'https://sentence.yourdictionary.com/flout',
#   'https://sentence.yourdictionary.com/homogeneous',
#   'https://sentence.yourdictionary.com/humdrum',
#   'https://sentence.yourdictionary.com/insipid',
#   'https://sentence.yourdictionary.com/loquacious',
# ...

# %%
finalWords = pd.DataFrame(allWords)

# %%
finalWords['Group 10']
# Out:
# 0            https://sentence.yourdictionary.com/acumen
# 1        https://sentence.yourdictionary.com/antithesis
# 2           https://sentence.yourdictionary.com/ascribe
# 3         https://sentence.yourdictionary.com/befuddled
# 4            https://sentence.yourdictionary.com/eschew
# 5          https://sentence.yourdictionary.com/esoteric
# 6           https://sentence.yourdictionary.com/evasive
# 7         https://sentence.yourdictionary.com/exculpate
# 8          https://sentence.yourdictionary.com/expedite
# 9        https://sentence.yourdictionary.com/fastidious
# 10            https://sentence.yourdictionary.com/feign
# 11          https://sentence.yourdictionary.com/furtive
# 12           https://sentence.yourdictionary.com/hamper
# 13    https://sentence.yourdictionary.com/indispensable
# 14           https://sentence.yourdictionary.com/lament
# 15           https://sentence.yourdictionary.com/myopic
# 16       https://sentence.yourdictionary.com/nonchalant
# ...

# %%
finalWords.to_excel("Example Sentences Your Dick.xlsx")
